# %% [markdown]
# <aside>
#
# Question-1:
#
# Given a Binary Tree (Bt), convert it to a Doubly Linked List(DLL). The left and right pointers in nodes are to be used as previous and next pointers respectively in converted DLL. The order of nodes in DLL must be the same as in Inorder for the given Binary Tree. The first node of Inorder traversal (leftmost node in BT) must be the head node of the DLL.
#
# Example:
#
# ![Alt text](https://pwskills.notion.site/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Ff9dda6ae-60b9-427b-990f-dc5b3117a5e3%2FUntitled.png?id=f5542efd-4d64-4904-9259-23aeb80f012b&table=block&spaceId=6fae2e0f-dedc-48e9-bc59-af2654c78209&width=860&userId=&cache=v2)
#
# </aside>

# %%
class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None

def convert_BT_to_DLL(root):
    if root is None:
        return None

    prev = None
    head = convert_BT_to_DLL(root.left)
    if head is not None:
        while head.right is not None:
            head = head.right
        head.right = root
        root.left = head

    tail = convert_BT_to_DLL(root.right)

    if tail is not None:
        while tail.left is not None:
            tail = tail.left
        tail.left = root
        root.right = tail

    return root if head is None else head

def DLL_forward(head):
    if head is None:
        return
    while head is not None:
        print(head.val, end=" ")
        head = head.right
    print()

def DLL_backward(tail):
    if tail is None:
        return
    while tail is not None:
        print(tail.val, end=" ")
        tail = tail.left
    print()

root = TreeNode(10)
root.left = TreeNode(12)
root.right = TreeNode(15)
root.left.left = TreeNode(25)
root.left.right = TreeNode(30)
root.right.left = TreeNode(36)

head = convert_BT_to_DLL(root)

print("DLL forward:")
DLL_forward(head)

print("DLL backward:")
DLL_backward(root.right.right)
# Out:
# DLL forward:
# 30 10 36 15
# DLL backward:
# 15 36 10 30 12 25

# %%
class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None

def convert_BT_to_DLL(root):
    if root is None:
        return None, None

    if root.left is None and root.right is None:
        return root, root

    head = None
    tail = None

    if root.left is not None:
        left_head, left_tail = convert_BT_to_DLL(root.left)
        head = left_head
        tail = left_tail

        tail.right = root
        root.left = tail
        tail = root

    if root.right is not None:
        right_head, right_tail = convert_BT_to_DLL(root.right)
        if head is None:
            head = right_head
        root.right = right_head
        right_head.left = root
        tail = right_tail

    return head, tail

def DLL_forward(head):
    if head is None:
        return
    while head is not None:
        print(head.val, end=" ")
        head = head.right
    print()

def DLL_backward(tail):
    if tail is None:
        return
    while tail is not None:
        print(tail.val, end=" ")
        tail = tail.left
    print()

root = TreeNode(10)
root.left = TreeNode(12)
root.right = TreeNode(15)
root.left.left = TreeNode(25)
root.left.right = TreeNode(30)
root.right.left = TreeNode(36)

head, _ = convert_BT_to_DLL(root)

print("DLL forward:")
DLL_forward(head)

print("DLL backward:")
DLL_backward(root.right.right)
# Out:
# DLL forward:
# 25 12 30 10 36 15
# DLL backward:
# 15 36 10 30 12 25

# %% [markdown]
# <aside>
#
# Question-2
#
# A Given a binary tree, the task is to flip the binary tree towards the right direction that is clockwise. See the below examples to see the transformation.
#
# In the flip operation, the leftmost node becomes the root of the flipped tree and its parent becomes its right child and the right sibling becomes its left child and the same should be done for all left most nodes recursively.
#
# Example1:
#
# ![Untitled](https://file.notion.so/f/s/a5f5bbbe-8607-4f17-9ab4-b31327ffa2d0/Untitled.png?id=bf2642e8-4284-4d78-9cf8-ea00a926b238&table=block&spaceId=6fae2e0f-dedc-48e9-bc59-af2654c78209&expirationTimestamp=1689350400000&signature=gkWG-YsCvb8yEOhcI3U-GTvCgHBt5y3LNAE0SrDeRC4&downloadName=Untitled.png)
#
# Example2:
#
# ![Untitled](https://pwskills.notion.site/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2F063636b4-9f35-4524-b6d9-c97e30cac510%2FUntitled.png?id=257a6e42-4876-4a44-ac0e-07f80a570f83&table=block&spaceId=6fae2e0f-dedc-48e9-bc59-af2654c78209&width=860&userId=&cache=v2)
#
# </aside>

# %%
class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None

def flip_binary_tree_clockwise(root):
    if root is None:
        return None

    if root.left is None and root.right is None:
        return root

    flipped_left = flip_binary_tree_clockwise(root.left)
    flipped_right = flip_binary_tree_clockwise(root.right)

    root.left = flipped_right
    root.right = flipped_left

    return root

def display_binary_tree(root):
    if root is None:
        return

    print(root.val, end=" ")
    display_binary_tree(root.left)
    display_binary_tree(root.right)


root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.left = TreeNode(6)
root.right.right = TreeNode(7)

print("Original binary tree:")
display_binary_tree(root)
flipped_root = flip_binary_tree_clockwise(root)

print("\nFlipped binary tree:")
display_binary_tree(flipped_root)
# Out:
# Original binary tree:
# 1 2 4 5 3 6 7
# Flipped binary tree:
# 1 3 7 6 2 5 4

# %% [markdown]
# <aside>
# 💡 Question-3:
#
# Given a binary tree, print all its root-to-leaf paths without using recursion. For example, consider the following Binary Tree.
#
# Input:
#
#         6
#      /    \
#     3      5
#   /   \     \
#  2     5     4
#      /   \
#     7     4
#
# Output:
#
# There are 4 leaves, hence 4 root to leaf paths -
#   6->3->2
#   6->3->5->7
#   6->3->5->4
#   6->5>4
#
# </aside>

# %%
class TreeNode:
    def __init__(self, value):
        self.val = value
        self.left = None
        self.right = None

def root_to_leaf_path(root):
    if root is None:
        return
    stack = []
    stack.append((root, str(root.val)))

    while stack:
        node, path = stack.pop()

        if node.left is None and node.right is None:
            print(path)
        
        if node.right is not None:
            stack.append((node.right, path + "->" + str(node.right.val)))
        
        if node.left is not None:
            stack.append((node.left, path + "->" + str(node.left.val)))


root = TreeNode(6)
root.left = TreeNode(3)
root.right = TreeNode(5)
root.left.left = TreeNode(2)
root.left.right = TreeNode(5)
root.right.right = TreeNode(4)
root.left.right.left = TreeNode(7)
root.left.right.right = TreeNode(4)

root_to_leaf_path(root)
# Out:
# 6->3->2
# 6->3->5->7
# 6->3->5->4
# 6->5->4

# %% [markdown]
# <aside>
# 💡 Question-4:
#
# Given Preorder, Inorder and Postorder traversals of some tree. Write a program to check if they all are of the same tree.
#
# **Examples:**
#
# Input :
#
#         Inorder -> 4 2 5 1 3
#         Preorder -> 1 2 4 5 3
#         Postorder -> 4 5 2 3 1
# Output :
#
# Yes
# Explanation :
#
# All of the above three traversals are of
# the same tree
#
#                            1
#                          /   \
#                         2     3
#                       /   \
#                      4     5
#
# Input :
#
#         Inorder -> 4 2 5 1 3
#         Preorder -> 1 5 4 2 3
#         Postorder -> 4 1 2 3 5
# Output :
#
# No
#
# </aside>

# %%
def check_for_same_tree(preorder, inorder, postorder):
    if len(preorder) != len(inorder) or len(preorder) != len(postorder):
        return False

    def check_for_same_tree_recursive(preorder, inorder, postorder):
        if not preorder:
            return True

        if preorder[0] != postorder[-1]:
            return False

        idx = inorder.index(preorder[0])

        left_preorder = preorder[1:idx+1]
        left_inorder = inorder[:idx]
        left_postorder = postorder[:idx]

        right_preorder = preorder[idx+1:]
        right_inorder = inorder[idx+1:]
        right_postorder = postorder[idx:-1]

        return check_for_same_tree_recursive(left_preorder, left_inorder, left_postorder) and \
               check_for_same_tree_recursive(right_preorder, right_inorder, right_postorder)

    return check_for_same_tree_recursive(preorder, inorder, postorder)

# Example usage
inorder = [4, 2, 5, 1, 3]
preorder = [1, 2, 4, 5, 3]
postorder = [4, 5, 2, 3, 1]
print(check_for_same_tree(preorder, inorder, postorder)) 

inorder = [4, 2, 5, 1, 3]
preorder = [1, 5, 4, 2, 3]
postorder = [4, 1, 2, 3, 5]
print(check_for_same_tree(preorder, inorder, postorder))
# Out:
# True
# False
